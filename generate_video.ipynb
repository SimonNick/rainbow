# %% [markdown]
# # Train

# %% [markdown]
# See `experiments.txt` for more examples

# %%
# !python main.py \
--buffer-size 1000000 \
--lr 5e-5 \
--batch-size 1024 \
--max-frames 12000 \
--checkpoint-freq 500000 \
--env Breakout-ram-v4 \
--prioritized-replay \
--save-model "test" \
--update-target 1000
# Out:
# /home/simon/.conda/envs/python_3.9/lib/python3.9/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272204863/work/c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0
# Arguments
# =============
# seed = 0
# batch_size = 1024
# no_cuda = False
# max_frames = 12000
# buffer_size = 1000000
# update_target = 1000
# train_freq = 1
# checkpoint_freq = 500000
# gamma = 0.99
# learning_start = 10000
# eps_start = 1.0
# eps_final = 0.01
# eps_decay = 30000
# double = False
# dueling = False
# noisy = False
# prioritized_replay = True
# c51 = False
# multi_step = 1
# Vmin = -10
# Vmax = 10
# num_atoms = 51
# alpha = 0.6
# beta_start = 0.4
# beta_frames = 100000
# sigma_init = 0.4
# env = Breakout-ram-v4
# episode_life = 1
# clip_rewards = 1
# frame_stack = 1
# scale = 0
# load_model = None
# load_checkpoint = None
# save_model = test
# evaluate = False
# render = False
# evaluation_interval = 10000
# logging = False
# lr = 5e-05
# cuda = False
# device = cpu
#
# Game:  Breakout-ram-v4
# Model: per-dqn
#
# A.L.E: Arcade Learning Environment (version +978d2ce)
# [Powered by Stella]
# Frame:    10000 / 12000	Episode: 34	FPS: 3288.31	Avg. Reward: 2.09	Avg. Length: 289.91	Avg. Loss: 0.000000
# Frame:    12000 / 12000	Episode: 42

# %% [markdown]
# # Evaluate

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# !python main.py \
--render \
--evaluate \
--batch-size 1024 \
--dueling \
--multi-step 3 \
--load-model 3-step-c51-per-dueling-double-noisy-dqn-breakout \
--env Breakout-ram-v4 \
--seed 10 \
--double \
--noisy \
--prioritized-replay \
--c51
# Out:
# /home/simon/.conda/envs/python_3.9/lib/python3.9/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272204863/work/c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0
# Arguments
# =============
# seed = 10
# batch_size = 1024
# no_cuda = False
# max_frames = 1400000
# buffer_size = 100000
# update_target = 1000
# train_freq = 1
# checkpoint_freq = None
# gamma = 0.99
# learning_start = 10000
# eps_start = 1.0
# eps_final = 0.01
# eps_decay = 30000
# double = True
# dueling = True
# noisy = True
# prioritized_replay = True
# c51 = True
# multi_step = 3
# Vmin = -10
# Vmax = 10
# num_atoms = 51
# alpha = 0.6
# beta_start = 0.4
# beta_frames = 100000
# sigma_init = 0.4
# env = Breakout-ram-v4
# episode_life = 1
# clip_rewards = 1
# frame_stack = 1
# scale = 0
# load_model = 3-step-c51-per-dueling-double-noisy-dqn-breakout
# load_checkpoint = None
# save_model = model
# evaluate = True
# render = True
# evaluation_interval = 10000
# logging = False
# lr = 0.0001
# cuda = False
# device = cpu
#
# Game:  Breakout-ram-v4
# Model: 3-step-c51-per-dueling-double-noisy-dqn
#
# A.L.E: Arcade Learning Environment (version +978d2ce)
# [Powered by Stella]
# /home/simon/.conda/envs/python_3.9/lib/python3.9/site-packages/gym/envs/atari/environment.py:255: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# Test Result - Reward 214.0 Length 3743

# %% [markdown]
# # Display video

# %%
import glob
import io
import base64

from IPython import display as ipythondisplay
from IPython.display import HTML

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")

# %%
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
